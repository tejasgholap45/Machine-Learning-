# %% [markdown]
# <a href="https://colab.research.google.com/github/tejasgholap45/Machine-Learning-/blob/main/Classification_MiniProject1_Mobile_ML_Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("iabhishekofficial/mobile-price-classification")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'mobile-price-classification' dataset.
# Path to dataset files: /kaggle/input/mobile-price-classification

# %%
import pandas as pd

df1 = pd.read_csv(f"{path}/train.csv")

df2 = pd.read_csv(f"{path}/test.csv")

# %%
# deal
#Bob contacts raj -300 * 10000-->
((300 * 1000) + 300000 + 2000)/4
# Out:
# 150500.0

# %%
# Bob ---pays 150500.0

# %%
# buiding the models


df1
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#how many phones for each price range?
df1['price_range'].value_counts()
# Out:
# price_range
# 1    500
# 2    500
# 3    500
# 0    500
# Name: count, dtype: int64

# %%
# X and Y

df1.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
x = df1[['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi']]


y = df1['price_range']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=12)

# %%
# call the models
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
knn_model = KNeighborsClassifier()
NB_model  = GaussianNB()
LR_model  = LogisticRegression()
svm_model = SVC()

# %%
# Train the models

knn_model.fit(x_train,y_train)

NB_model.fit(x_train,y_train)

LR_model.fit(x_train,y_train)

svm_model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# SVC()

# %%
# testing

y_pred_knn = knn_model.predict(x_test)
y_pred_NB  = NB_model.predict(x_test)
y_pred_LR  = LR_model.predict(x_test)
y_pred_svm = svm_model.predict(x_test)

# %%
# Evaluation

print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       102
#            1       0.91      0.90      0.91       105
#            2       0.85      0.86      0.86        95
#            3       0.92      0.92      0.92        98
#
#     accuracy                           0.91       400
#    macro avg       0.91      0.91      0.91       400
# weighted avg       0.91      0.91      0.91       400

# %%
# Evaluation

print(classification_report(y_test,y_pred_NB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90       102
#            1       0.77      0.70      0.74       105
#            2       0.71      0.83      0.76        95
#            3       0.92      0.93      0.92        98
#
#     accuracy                           0.83       400
#    macro avg       0.84      0.83      0.83       400
# weighted avg       0.84      0.83      0.83       400

# %%
# Evaluation

print(classification_report(y_test,y_pred_LR))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.77      0.83       102
#            1       0.61      0.56      0.59       105
#            2       0.53      0.53      0.53        95
#            3       0.69      0.86      0.77        98
#
#     accuracy                           0.68       400
#    macro avg       0.68      0.68      0.68       400
# weighted avg       0.68      0.68      0.68       400

# %%
# Evaluation

print(classification_report(y_test,y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       102
#            1       0.97      0.96      0.97       105
#            2       0.92      0.93      0.92        95
#            3       0.95      0.93      0.94        98
#
#     accuracy                           0.95       400
#    macro avg       0.95      0.95      0.95       400
# weighted avg       0.95      0.95      0.95       400

# %%
# Best model is svm for this data 95%

#see if the data is allined |

# I need to remove the "ID" col

# %%
# remove the ID col

df2.drop("id",axis = 1,inplace=True)

# %%
x_train.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
df2.columns ==  x_train.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
df2["Predicted_price"]  = svm_model.predict(df2)

# %%
df2
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df2.to_csv("Final.csv")

# %%
import pickle

with open("best_ml.pkl","wb") as f:
  pickle.dump(svm_model,f)
